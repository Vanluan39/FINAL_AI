# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanluan39/FINAL_AI/blob/main/Facial_1Acupoint_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 0. Link colab với Drive
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#####  LOADING AND EXTRACTING DATA   #####
##import các thư viện
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import shuffle


def data_loader():
    
    # Load dataset file
    data_frame = pd.read_csv('/content/drive/MyDrive/FINAL_AI/FINAL_AI/training.csv')
    # xử lí ảnh
    data_frame['Image'] = data_frame['Image'].apply(lambda i: np.fromstring(i, sep=' '))
    # loại bỏ dữ liệu còn thiếu
    data_frame = data_frame.dropna()  # Get only the data with 15 keypoints
   
    # Extract Images pixel values
    #trích xuất giá trị pixel của ảnh từ cột
    imgs_array = np.vstack(data_frame['Image'].values)/ 255.0
    #chuyển đổi kiểu dữ liệu
    imgs_array = imgs_array.astype(np.float32)    # Normalize, target values to (0, 1)
    imgs_array = imgs_array.reshape(-1, 96, 96, 1)
        
    # Extract labels (key point cords)
    labels_array = data_frame[data_frame.columns[:-1]].values
    labels_array = (labels_array - 48) / 48    # Normalize, traget cordinates to (-1, 1)
    labels_array = labels_array.astype(np.float32) 
    
    # shuffle the train data
    imgs_array, labels_array = shuffle(imgs_array, labels_array, random_state=9)  
    
    return imgs_array, labels_array

# %%
######   BUILD, TRAIN AND SAVE THE CONVOLUTIONAL MODEL    ########

#import các thư viện
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, GlobalAveragePooling2D, Activation
from keras.layers import Flatten, Dense
from tensorflow.keras.layers import BatchNormalization
from keras import optimizers
from keras.callbacks import ModelCheckpoint, History
#from keras.optimizers import Adam


# Main model
#xây dựng một mô hình mạng nơ-ron sử dụng kiến trúc CNN
def the_model():
  #Khởi tạo một đối tượng Sequential
    model = Sequential()
    #Thêm một lớp Conv2D vào mô hình với 16 bộ lọc, kích thước bộ lọc là (3,3)
    model.add(Conv2D(16, (3,3), padding='same', activation='relu', input_shape=X_train.shape[1:])) # Input shape: (96, 96, 1)
    #Thêm một lớp MaxPooling2D để giảm kích thước đầu ra
    model.add(MaxPooling2D(pool_size=2))
    
    model.add(Conv2D(32, (3,3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=2))
    
    model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=2))
    
    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=2))
    
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=2))
    
    # Convert all values to 1D array
    model.add(Flatten())
    
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    model.add(Dense(30))
    
    return model

#tải dữ liệu huấn luyện và gán kết quả
X_train, y_train = data_loader()
#In ra thông tin về kích thước của dữ liệu huấn luyện
print("Training datapoint shape: X_train.shape:{}".format(X_train.shape))
print("Training labels shape: y_train.shape:{}".format(y_train.shape))

#vòng lặp huấn luyện
epochs = 100
#Đặt giá trị cho mỗi batch
batch_size = 64
# khởi tạo mô hình mạng nơ-ron và lưu thông tin
model = the_model()
hist = History()

#lưu trữ trọng số của mô hình 
checkpointer = ModelCheckpoint(filepath='/content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5', 
                               verbose=1, save_best_only=True)

# Complie Model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
#Huấn luyện mô hình trên dữ liệu huấn luyện 
model_fit = model.fit(X_train, y_train, validation_split=0.2, epochs=epochs, batch_size=batch_size, callbacks=[checkpointer, hist], verbose=1)
#Lưu trữ mô hình đã huấn luyện
model.save('/content/drive/MyDrive/FINAL_AI/FINAL_AI/model1.h5')
# Out:
# Training datapoint shape: X_train.shape:(2140, 96, 96, 1)
# Training labels shape: y_train.shape:(2140, 30)
# Epoch 1/100
# 27/27 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 0.4504
# Epoch 1: val_loss improved from inf to 0.00990, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 15s 95ms/step - loss: 0.0429 - accuracy: 0.4504 - val_loss: 0.0099 - val_accuracy: 0.7126
# Epoch 2/100
# 24/27 [=========================>....] - ETA: 0s - loss: 0.0106 - accuracy: 0.5553
# Epoch 2: val_loss improved from 0.00990 to 0.00595, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0104 - accuracy: 0.5619 - val_loss: 0.0060 - val_accuracy: 0.7126
# Epoch 3/100
# 24/27 [=========================>....] - ETA: 0s - loss: 0.0078 - accuracy: 0.6048
# Epoch 3: val_loss improved from 0.00595 to 0.00484, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0077 - accuracy: 0.6028 - val_loss: 0.0048 - val_accuracy: 0.7126
# Epoch 4/100
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0067 - accuracy: 0.6121
# Epoch 4: val_loss did not improve from 0.00484
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0066 - accuracy: 0.6192 - val_loss: 0.0050 - val_accuracy: 0.7126
# Epoch 5/100
# 24/27 [=========================>....] - ETA: 0s - loss: 0.0061 - accuracy: 0.6374
# Epoch 5: val_loss improved from 0.00484 to 0.00466, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0061 - accuracy: 0.6320 - val_loss: 0.0047 - val_accuracy: 0.7126
# Epoch 6/100
# 27/27 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.6408
# Epoch 6: val_loss improved from 0.00466 to 0.00459, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0058 - accuracy: 0.6408 - val_loss: 0.0046 - val_accuracy: 0.7126
# Epoch 7/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0057 - accuracy: 0.6500
# Epoch 7: val_loss improved from 0.00459 to 0.00452, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0057 - accuracy: 0.6513 - val_loss: 0.0045 - val_accuracy: 0.7126
# Epoch 8/100
# 27/27 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.6636
# Epoch 8: val_loss did not improve from 0.00452
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0054 - accuracy: 0.6636 - val_loss: 0.0049 - val_accuracy: 0.7126
# Epoch 9/100
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0053 - accuracy: 0.6630
# Epoch 9: val_loss improved from 0.00452 to 0.00431, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 0s 19ms/step - loss: 0.0053 - accuracy: 0.6688 - val_loss: 0.0043 - val_accuracy: 0.7126
# Epoch 10/100
# 27/27 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.6618
# Epoch 10: val_loss did not improve from 0.00431
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0050 - accuracy: 0.6618 - val_loss: 0.0043 - val_accuracy: 0.7126
# Epoch 11/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0048 - accuracy: 0.6544
# Epoch 11: val_loss improved from 0.00431 to 0.00415, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0048 - accuracy: 0.6565 - val_loss: 0.0041 - val_accuracy: 0.7126
# Epoch 12/100
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0046 - accuracy: 0.6821
# Epoch 12: val_loss improved from 0.00415 to 0.00393, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0046 - accuracy: 0.6770 - val_loss: 0.0039 - val_accuracy: 0.7103
# Epoch 13/100
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0044 - accuracy: 0.6814
# Epoch 13: val_loss improved from 0.00393 to 0.00390, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0044 - accuracy: 0.6793 - val_loss: 0.0039 - val_accuracy: 0.7103
# Epoch 14/100
# 24/27 [=========================>....] - ETA: 0s - loss: 0.0042 - accuracy: 0.6849
# Epoch 14: val_loss improved from 0.00390 to 0.00380, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0042 - accuracy: 0.6828 - val_loss: 0.0038 - val_accuracy: 0.7126
# Epoch 15/100
# 27/27 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.6898
# Epoch 15: val_loss improved from 0.00380 to 0.00355, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0041 - accuracy: 0.6898 - val_loss: 0.0036 - val_accuracy: 0.7150
# Epoch 16/100
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0038 - accuracy: 0.6834
# Epoch 16: val_loss improved from 0.00355 to 0.00325, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0037 - accuracy: 0.6869 - val_loss: 0.0032 - val_accuracy: 0.7150
# Epoch 17/100
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0035 - accuracy: 0.6943
# Epoch 17: val_loss improved from 0.00325 to 0.00300, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0035 - accuracy: 0.7009 - val_loss: 0.0030 - val_accuracy: 0.7243
# Epoch 18/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0032 - accuracy: 0.7073
# Epoch 18: val_loss improved from 0.00300 to 0.00282, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0032 - accuracy: 0.7056 - val_loss: 0.0028 - val_accuracy: 0.7453
# Epoch 19/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0030 - accuracy: 0.7055
# Epoch 19: val_loss improved from 0.00282 to 0.00254, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0029 - accuracy: 0.7039 - val_loss: 0.0025 - val_accuracy: 0.7360
# Epoch 20/100
# 24/27 [=========================>....] - ETA: 0s - loss: 0.0027 - accuracy: 0.7051
# Epoch 20: val_loss did not improve from 0.00254
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0027 - accuracy: 0.7085 - val_loss: 0.0028 - val_accuracy: 0.7407
# Epoch 21/100
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0026 - accuracy: 0.7412
# Epoch 21: val_loss improved from 0.00254 to 0.00250, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0026 - accuracy: 0.7395 - val_loss: 0.0025 - val_accuracy: 0.7874
# Epoch 22/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0025 - accuracy: 0.7302
# Epoch 22: val_loss improved from 0.00250 to 0.00220, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0025 - accuracy: 0.7272 - val_loss: 0.0022 - val_accuracy: 0.7617
# Epoch 23/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0022 - accuracy: 0.7450
# Epoch 23: val_loss improved from 0.00220 to 0.00200, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0022 - accuracy: 0.7442 - val_loss: 0.0020 - val_accuracy: 0.7850
# Epoch 24/100
# 24/27 [=========================>....] - ETA: 0s - loss: 0.0021 - accuracy: 0.7285
# Epoch 24: val_loss did not improve from 0.00200
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0021 - accuracy: 0.7266 - val_loss: 0.0021 - val_accuracy: 0.7944
# Epoch 25/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0021 - accuracy: 0.7494
# Epoch 25: val_loss improved from 0.00200 to 0.00192, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0021 - accuracy: 0.7494 - val_loss: 0.0019 - val_accuracy: 0.7827
# Epoch 26/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0020 - accuracy: 0.7481
# Epoch 26: val_loss improved from 0.00192 to 0.00187, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0020 - accuracy: 0.7482 - val_loss: 0.0019 - val_accuracy: 0.7967
# Epoch 27/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0019 - accuracy: 0.7525
# Epoch 27: val_loss did not improve from 0.00187
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0019 - accuracy: 0.7518 - val_loss: 0.0020 - val_accuracy: 0.7921
# Epoch 28/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0019 - accuracy: 0.7494
# Epoch 28: val_loss improved from 0.00187 to 0.00175, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0019 - accuracy: 0.7500 - val_loss: 0.0018 - val_accuracy: 0.7827
# Epoch 29/100
# 24/27 [=========================>....] - ETA: 0s - loss: 0.0018 - accuracy: 0.7611
# Epoch 29: val_loss did not improve from 0.00175
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0018 - accuracy: 0.7582 - val_loss: 0.0019 - val_accuracy: 0.8014
# Epoch 30/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0017 - accuracy: 0.7794
# Epoch 30: val_loss improved from 0.00175 to 0.00172, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0017 - accuracy: 0.7810 - val_loss: 0.0017 - val_accuracy: 0.7944
# Epoch 31/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 0.7620
# Epoch 31: val_loss did not improve from 0.00172
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0016 - accuracy: 0.7611 - val_loss: 0.0018 - val_accuracy: 0.8107
# Epoch 32/100
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0017 - accuracy: 0.7649
# Epoch 32: val_loss improved from 0.00172 to 0.00171, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0017 - accuracy: 0.7617 - val_loss: 0.0017 - val_accuracy: 0.7804
# Epoch 33/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 0.7764
# Epoch 33: val_loss improved from 0.00171 to 0.00160, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0016 - accuracy: 0.7763 - val_loss: 0.0016 - val_accuracy: 0.8014
# Epoch 34/100
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0016 - accuracy: 0.7738
# Epoch 34: val_loss did not improve from 0.00160
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0016 - accuracy: 0.7745 - val_loss: 0.0017 - val_accuracy: 0.8037
# Epoch 35/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0015 - accuracy: 0.7831
# Epoch 35: val_loss improved from 0.00160 to 0.00157, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0015 - accuracy: 0.7827 - val_loss: 0.0016 - val_accuracy: 0.7991
# Epoch 36/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0014 - accuracy: 0.7879
# Epoch 36: val_loss did not improve from 0.00157
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0014 - accuracy: 0.7886 - val_loss: 0.0016 - val_accuracy: 0.8107
# Epoch 37/100
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0014 - accuracy: 0.7887
# Epoch 37: val_loss did not improve from 0.00157
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0014 - accuracy: 0.7897 - val_loss: 0.0016 - val_accuracy: 0.7944
# Epoch 38/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0014 - accuracy: 0.7788
# Epoch 38: val_loss improved from 0.00157 to 0.00154, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0014 - accuracy: 0.7792 - val_loss: 0.0015 - val_accuracy: 0.8061
# Epoch 39/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0014 - accuracy: 0.7927
# Epoch 39: val_loss did not improve from 0.00154
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0014 - accuracy: 0.7926 - val_loss: 0.0017 - val_accuracy: 0.8061
# Epoch 40/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0014 - accuracy: 0.7987
# Epoch 40: val_loss improved from 0.00154 to 0.00151, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0014 - accuracy: 0.7961 - val_loss: 0.0015 - val_accuracy: 0.8084
# Epoch 41/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0013 - accuracy: 0.7999
# Epoch 41: val_loss improved from 0.00151 to 0.00147, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0013 - accuracy: 0.7973 - val_loss: 0.0015 - val_accuracy: 0.8201
# Epoch 42/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 0.7945
# Epoch 42: val_loss did not improve from 0.00147
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0012 - accuracy: 0.7961 - val_loss: 0.0015 - val_accuracy: 0.8084
# Epoch 43/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 0.8143
# Epoch 43: val_loss improved from 0.00147 to 0.00146, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0012 - accuracy: 0.8137 - val_loss: 0.0015 - val_accuracy: 0.7850
# Epoch 44/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0013 - accuracy: 0.7962
# Epoch 44: val_loss improved from 0.00146 to 0.00144, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0013 - accuracy: 0.7956 - val_loss: 0.0014 - val_accuracy: 0.8014
# Epoch 45/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 0.7975
# Epoch 45: val_loss improved from 0.00144 to 0.00143, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0012 - accuracy: 0.7956 - val_loss: 0.0014 - val_accuracy: 0.8178
# Epoch 46/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0012 - accuracy: 0.8006
# Epoch 46: val_loss did not improve from 0.00143
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0012 - accuracy: 0.8020 - val_loss: 0.0015 - val_accuracy: 0.8201
# Epoch 47/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 0.8077
# Epoch 47: val_loss did not improve from 0.00143
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0011 - accuracy: 0.8067 - val_loss: 0.0019 - val_accuracy: 0.7921
# Epoch 48/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0013 - accuracy: 0.8095
# Epoch 48: val_loss did not improve from 0.00143
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0013 - accuracy: 0.8084 - val_loss: 0.0015 - val_accuracy: 0.8154
# Epoch 49/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 0.8047
# Epoch 49: val_loss did not improve from 0.00143
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0012 - accuracy: 0.8061 - val_loss: 0.0015 - val_accuracy: 0.8178
# Epoch 50/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0011 - accuracy: 0.8087
# Epoch 50: val_loss did not improve from 0.00143
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0011 - accuracy: 0.8107 - val_loss: 0.0015 - val_accuracy: 0.8014
# Epoch 51/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0010 - accuracy: 0.8244
# Epoch 51: val_loss did not improve from 0.00143
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0010 - accuracy: 0.8242 - val_loss: 0.0015 - val_accuracy: 0.8131
# Epoch 52/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0010 - accuracy: 0.8050
# Epoch 52: val_loss improved from 0.00143 to 0.00140, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0010 - accuracy: 0.8067 - val_loss: 0.0014 - val_accuracy: 0.8131
# Epoch 53/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0011 - accuracy: 0.8106
# Epoch 53: val_loss did not improve from 0.00140
# 27/27 [==============================] - 0s 19ms/step - loss: 0.0011 - accuracy: 0.8131 - val_loss: 0.0014 - val_accuracy: 0.8037
# Epoch 54/100
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0010 - accuracy: 0.8209
# Epoch 54: val_loss did not improve from 0.00140
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0010 - accuracy: 0.8236 - val_loss: 0.0014 - val_accuracy: 0.8224
# Epoch 55/100
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0010 - accuracy: 0.8263
# Epoch 55: val_loss did not improve from 0.00140
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0010 - accuracy: 0.8259 - val_loss: 0.0014 - val_accuracy: 0.8061
# Epoch 56/100
# 25/27 [==========================>...] - ETA: 0s - loss: 9.8385e-04 - accuracy: 0.8194
# Epoch 56: val_loss did not improve from 0.00140
# 27/27 [==============================] - 0s 18ms/step - loss: 9.8210e-04 - accuracy: 0.8154 - val_loss: 0.0014 - val_accuracy: 0.8154
# Epoch 57/100
# 25/27 [==========================>...] - ETA: 0s - loss: 9.5720e-04 - accuracy: 0.8275
# Epoch 57: val_loss did not improve from 0.00140
# 27/27 [==============================] - 0s 16ms/step - loss: 9.5805e-04 - accuracy: 0.8283 - val_loss: 0.0014 - val_accuracy: 0.7921
# Epoch 58/100
# 26/27 [===========================>..] - ETA: 0s - loss: 9.5517e-04 - accuracy: 0.8227
# Epoch 58: val_loss did not improve from 0.00140
# 27/27 [==============================] - 0s 17ms/step - loss: 9.5496e-04 - accuracy: 0.8236 - val_loss: 0.0014 - val_accuracy: 0.8131
# Epoch 59/100
# 26/27 [===========================>..] - ETA: 0s - loss: 9.5351e-04 - accuracy: 0.8221
# Epoch 59: val_loss did not improve from 0.00140
# 27/27 [==============================] - 0s 15ms/step - loss: 9.5573e-04 - accuracy: 0.8230 - val_loss: 0.0015 - val_accuracy: 0.8248
# Epoch 60/100
# 25/27 [==========================>...] - ETA: 0s - loss: 9.4925e-04 - accuracy: 0.8100
# Epoch 60: val_loss improved from 0.00140 to 0.00138, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 19ms/step - loss: 9.5176e-04 - accuracy: 0.8125 - val_loss: 0.0014 - val_accuracy: 0.8341
# Epoch 61/100
# 23/27 [========================>.....] - ETA: 0s - loss: 9.1382e-04 - accuracy: 0.8240
# Epoch 61: val_loss did not improve from 0.00138
# 27/27 [==============================] - 0s 16ms/step - loss: 9.1287e-04 - accuracy: 0.8242 - val_loss: 0.0014 - val_accuracy: 0.7967
# Epoch 62/100
# 23/27 [========================>.....] - ETA: 0s - loss: 9.9626e-04 - accuracy: 0.8370
# Epoch 62: val_loss did not improve from 0.00138
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0010 - accuracy: 0.8370 - val_loss: 0.0018 - val_accuracy: 0.7991
# Epoch 63/100
# 26/27 [===========================>..] - ETA: 0s - loss: 9.9725e-04 - accuracy: 0.8293
# Epoch 63: val_loss did not improve from 0.00138
# 27/27 [==============================] - 0s 15ms/step - loss: 9.9632e-04 - accuracy: 0.8300 - val_loss: 0.0014 - val_accuracy: 0.8154
# Epoch 64/100
# 26/27 [===========================>..] - ETA: 0s - loss: 9.0023e-04 - accuracy: 0.8281
# Epoch 64: val_loss improved from 0.00138 to 0.00137, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 19ms/step - loss: 8.9592e-04 - accuracy: 0.8312 - val_loss: 0.0014 - val_accuracy: 0.8388
# Epoch 65/100
# 25/27 [==========================>...] - ETA: 0s - loss: 8.8171e-04 - accuracy: 0.8325
# Epoch 65: val_loss did not improve from 0.00137
# 27/27 [==============================] - 0s 16ms/step - loss: 8.8068e-04 - accuracy: 0.8341 - val_loss: 0.0014 - val_accuracy: 0.8131
# Epoch 66/100
# 26/27 [===========================>..] - ETA: 0s - loss: 8.3779e-04 - accuracy: 0.8383
# Epoch 66: val_loss improved from 0.00137 to 0.00137, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 19ms/step - loss: 8.3883e-04 - accuracy: 0.8376 - val_loss: 0.0014 - val_accuracy: 0.7921
# Epoch 67/100
# 26/27 [===========================>..] - ETA: 0s - loss: 8.2773e-04 - accuracy: 0.8377
# Epoch 67: val_loss did not improve from 0.00137
# 27/27 [==============================] - 0s 15ms/step - loss: 8.2918e-04 - accuracy: 0.8382 - val_loss: 0.0014 - val_accuracy: 0.8107
# Epoch 68/100
# 26/27 [===========================>..] - ETA: 0s - loss: 8.5398e-04 - accuracy: 0.8486
# Epoch 68: val_loss did not improve from 0.00137
# 27/27 [==============================] - 0s 16ms/step - loss: 8.5622e-04 - accuracy: 0.8446 - val_loss: 0.0014 - val_accuracy: 0.8131
# Epoch 69/100
# 26/27 [===========================>..] - ETA: 0s - loss: 8.0207e-04 - accuracy: 0.8365
# Epoch 69: val_loss improved from 0.00137 to 0.00136, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 21ms/step - loss: 8.0405e-04 - accuracy: 0.8370 - val_loss: 0.0014 - val_accuracy: 0.8084
# Epoch 70/100
# 26/27 [===========================>..] - ETA: 0s - loss: 8.4356e-04 - accuracy: 0.8480
# Epoch 70: val_loss did not improve from 0.00136
# 27/27 [==============================] - 0s 17ms/step - loss: 8.4315e-04 - accuracy: 0.8475 - val_loss: 0.0014 - val_accuracy: 0.8341
# Epoch 71/100
# 26/27 [===========================>..] - ETA: 0s - loss: 8.3058e-04 - accuracy: 0.8510
# Epoch 71: val_loss improved from 0.00136 to 0.00135, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 21ms/step - loss: 8.3163e-04 - accuracy: 0.8493 - val_loss: 0.0014 - val_accuracy: 0.8248
# Epoch 72/100
# 26/27 [===========================>..] - ETA: 0s - loss: 7.9641e-04 - accuracy: 0.8413
# Epoch 72: val_loss improved from 0.00135 to 0.00134, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 21ms/step - loss: 7.9998e-04 - accuracy: 0.8417 - val_loss: 0.0013 - val_accuracy: 0.8084
# Epoch 73/100
# 26/27 [===========================>..] - ETA: 0s - loss: 8.2151e-04 - accuracy: 0.8450
# Epoch 73: val_loss did not improve from 0.00134
# 27/27 [==============================] - 0s 16ms/step - loss: 8.2229e-04 - accuracy: 0.8458 - val_loss: 0.0014 - val_accuracy: 0.8224
# Epoch 74/100
# 26/27 [===========================>..] - ETA: 0s - loss: 8.6869e-04 - accuracy: 0.8528
# Epoch 74: val_loss did not improve from 0.00134
# 27/27 [==============================] - 0s 15ms/step - loss: 8.6606e-04 - accuracy: 0.8522 - val_loss: 0.0014 - val_accuracy: 0.8061
# Epoch 75/100
# 26/27 [===========================>..] - ETA: 0s - loss: 7.8712e-04 - accuracy: 0.8444
# Epoch 75: val_loss improved from 0.00134 to 0.00133, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 19ms/step - loss: 7.8499e-04 - accuracy: 0.8446 - val_loss: 0.0013 - val_accuracy: 0.8294
# Epoch 76/100
# 27/27 [==============================] - ETA: 0s - loss: 7.8994e-04 - accuracy: 0.8417
# Epoch 76: val_loss did not improve from 0.00133
# 27/27 [==============================] - 0s 16ms/step - loss: 7.8994e-04 - accuracy: 0.8417 - val_loss: 0.0014 - val_accuracy: 0.8318
# Epoch 77/100
# 25/27 [==========================>...] - ETA: 0s - loss: 7.6766e-04 - accuracy: 0.8550
# Epoch 77: val_loss did not improve from 0.00133
# 27/27 [==============================] - 0s 15ms/step - loss: 7.6612e-04 - accuracy: 0.8540 - val_loss: 0.0014 - val_accuracy: 0.8154
# Epoch 78/100
# 26/27 [===========================>..] - ETA: 0s - loss: 7.4027e-04 - accuracy: 0.8540
# Epoch 78: val_loss did not improve from 0.00133
# 27/27 [==============================] - 0s 17ms/step - loss: 7.3682e-04 - accuracy: 0.8528 - val_loss: 0.0014 - val_accuracy: 0.8154
# Epoch 79/100
# 24/27 [=========================>....] - ETA: 0s - loss: 7.3625e-04 - accuracy: 0.8535
# Epoch 79: val_loss did not improve from 0.00133
# 27/27 [==============================] - 0s 18ms/step - loss: 7.3952e-04 - accuracy: 0.8534 - val_loss: 0.0014 - val_accuracy: 0.8271
# Epoch 80/100
# 24/27 [=========================>....] - ETA: 0s - loss: 7.4319e-04 - accuracy: 0.8639
# Epoch 80: val_loss did not improve from 0.00133
# 27/27 [==============================] - 1s 19ms/step - loss: 7.4656e-04 - accuracy: 0.8633 - val_loss: 0.0013 - val_accuracy: 0.8178
# Epoch 81/100
# 25/27 [==========================>...] - ETA: 0s - loss: 7.5697e-04 - accuracy: 0.8525
# Epoch 81: val_loss did not improve from 0.00133
# 27/27 [==============================] - 0s 18ms/step - loss: 7.5904e-04 - accuracy: 0.8475 - val_loss: 0.0014 - val_accuracy: 0.8201
# Epoch 82/100
# 25/27 [==========================>...] - ETA: 0s - loss: 7.4696e-04 - accuracy: 0.8544
# Epoch 82: val_loss did not improve from 0.00133
# 27/27 [==============================] - 1s 19ms/step - loss: 7.4722e-04 - accuracy: 0.8551 - val_loss: 0.0014 - val_accuracy: 0.8364
# Epoch 83/100
# 25/27 [==========================>...] - ETA: 0s - loss: 7.0473e-04 - accuracy: 0.8494
# Epoch 83: val_loss did not improve from 0.00133
# 27/27 [==============================] - 0s 18ms/step - loss: 7.0565e-04 - accuracy: 0.8470 - val_loss: 0.0014 - val_accuracy: 0.8178
# Epoch 84/100
# 24/27 [=========================>....] - ETA: 0s - loss: 7.2656e-04 - accuracy: 0.8639
# Epoch 84: val_loss did not improve from 0.00133
# 27/27 [==============================] - 0s 18ms/step - loss: 7.3737e-04 - accuracy: 0.8627 - val_loss: 0.0015 - val_accuracy: 0.8248
# Epoch 85/100
# 24/27 [=========================>....] - ETA: 0s - loss: 7.3189e-04 - accuracy: 0.8535
# Epoch 85: val_loss did not improve from 0.00133
# 27/27 [==============================] - 1s 19ms/step - loss: 7.2667e-04 - accuracy: 0.8575 - val_loss: 0.0014 - val_accuracy: 0.8248
# Epoch 86/100
# 25/27 [==========================>...] - ETA: 0s - loss: 6.8939e-04 - accuracy: 0.8700
# Epoch 86: val_loss improved from 0.00133 to 0.00132, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 21ms/step - loss: 6.8916e-04 - accuracy: 0.8662 - val_loss: 0.0013 - val_accuracy: 0.8294
# Epoch 87/100
# 25/27 [==========================>...] - ETA: 0s - loss: 6.9867e-04 - accuracy: 0.8631
# Epoch 87: val_loss did not improve from 0.00132
# 27/27 [==============================] - 0s 15ms/step - loss: 6.9374e-04 - accuracy: 0.8621 - val_loss: 0.0014 - val_accuracy: 0.8154
# Epoch 88/100
# 26/27 [===========================>..] - ETA: 0s - loss: 6.9144e-04 - accuracy: 0.8618
# Epoch 88: val_loss did not improve from 0.00132
# 27/27 [==============================] - 0s 17ms/step - loss: 6.9258e-04 - accuracy: 0.8610 - val_loss: 0.0013 - val_accuracy: 0.8271
# Epoch 89/100
# 26/27 [===========================>..] - ETA: 0s - loss: 7.1763e-04 - accuracy: 0.8600
# Epoch 89: val_loss improved from 0.00132 to 0.00130, saving model to /content/drive/MyDrive/FINAL_AI/FINAL_AI/checkpoint1.hdf5
# 27/27 [==============================] - 1s 20ms/step - loss: 7.1516e-04 - accuracy: 0.8610 - val_loss: 0.0013 - val_accuracy: 0.8107
# Epoch 90/100
# 25/27 [==========================>...] - ETA: 0s - loss: 6.8409e-04 - accuracy: 0.8569
# Epoch 90: val_loss did not improve from 0.00130
# 27/27 [==============================] - 0s 16ms/step - loss: 6.8732e-04 - accuracy: 0.8534 - val_loss: 0.0014 - val_accuracy: 0.8341
# Epoch 91/100
# 26/27 [===========================>..] - ETA: 0s - loss: 6.6117e-04 - accuracy: 0.8516
# Epoch 91: val_loss did not improve from 0.00130
# 27/27 [==============================] - 0s 15ms/step - loss: 6.5972e-04 - accuracy: 0.8540 - val_loss: 0.0013 - val_accuracy: 0.8061
# Epoch 92/100
# 26/27 [===========================>..] - ETA: 0s - loss: 6.4524e-04 - accuracy: 0.8570
# Epoch 92: val_loss did not improve from 0.00130
# 27/27 [==============================] - 0s 15ms/step - loss: 6.4496e-04 - accuracy: 0.8569 - val_loss: 0.0013 - val_accuracy: 0.8248
# Epoch 93/100
# 27/27 [==============================] - ETA: 0s - loss: 6.8043e-04 - accuracy: 0.8586
# Epoch 93: val_loss did not improve from 0.00130
# 27/27 [==============================] - 0s 16ms/step - loss: 6.8043e-04 - accuracy: 0.8586 - val_loss: 0.0014 - val_accuracy: 0.8131
# Epoch 94/100
# 25/27 [==========================>...] - ETA: 0s - loss: 6.4723e-04 - accuracy: 0.8650
# Epoch 94: val_loss did not improve from 0.00130
# 27/27 [==============================] - 0s 15ms/step - loss: 6.4521e-04 - accuracy: 0.8651 - val_loss: 0.0013 - val_accuracy: 0.8178
# Epoch 95/100
# 25/27 [==========================>...] - ETA: 0s - loss: 6.2407e-04 - accuracy: 0.8656
# Epoch 95: val_loss did not improve from 0.00130
# 27/27 [==============================] - 0s 15ms/step - loss: 6.3290e-04 - accuracy: 0.8616 - val_loss: 0.0013 - val_accuracy: 0.8318
# Epoch 96/100
# 26/27 [===========================>..] - ETA: 0s - loss: 6.2740e-04 - accuracy: 0.8456
# Epoch 96: val_loss did not improve from 0.00130
# 27/27 [==============================] - 0s 15ms/step - loss: 6.2609e-04 - accuracy: 0.8464 - val_loss: 0.0013 - val_accuracy: 0.8084
# Epoch 97/100
# 25/27 [==========================>...] - ETA: 0s - loss: 6.3263e-04 - accuracy: 0.8687
# Epoch 97: val_loss did not improve from 0.00130
# 27/27 [==============================] - 0s 17ms/step - loss: 6.3205e-04 - accuracy: 0.8668 - val_loss: 0.0014 - val_accuracy: 0.8131
# Epoch 98/100
# 26/27 [===========================>..] - ETA: 0s - loss: 6.1696e-04 - accuracy: 0.8630
# Epoch 98: val_loss did not improve from 0.00130
# 27/27 [==============================] - 0s 17ms/step - loss: 6.1622e-04 - accuracy: 0.8610 - val_loss: 0.0013 - val_accuracy: 0.8178
# Epoch 99/100
# 26/27 [===========================>..] - ETA: 0s - loss: 6.1390e-04 - accuracy: 0.8624
# Epoch 99: val_loss did not improve from 0.00130
# 27/27 [==============================] - 0s 15ms/step - loss: 6.1303e-04 - accuracy: 0.8627 - val_loss: 0.0013 - val_accuracy: 0.8318
# Epoch 100/100
# 26/27 [===========================>..] - ETA: 0s - loss: 6.0983e-04 - accuracy: 0.8528
# Epoch 100: val_loss did not improve from 0.00130
# 27/27 [==============================] - 0s 15ms/step - loss: 6.1087e-04 - accuracy: 0.8528 - val_loss: 0.0013 - val_accuracy: 0.8248

# %%
#####  TEST YOUR IMAGE FILE WITH THE MODEL  #####

#import các thư viện
import cv2
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
import time

# Load the saved model
from keras.models import load_model
model = load_model('/content/drive/MyDrive/FINAL_AI/FINAL_AI/model1.h5')  # <-- Saved model path

# dự đoán các điểm đặc trưng trên khuôn mặt
def detect_points(face_img):
    me  = np.array(face_img)/255
    x_test = np.expand_dims(me, axis=0)
    x_test = np.expand_dims(x_test, axis=3)

    y_test = model.predict(x_test)
    label_points = (np.squeeze(y_test)*48)+48 
    
    return label_points
    
# Load haarcascade
face_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/FINAL_AI/FINAL_AI/haarcascade_frontalface_alt.xml')
dimensions = (96, 96)

# Enter the path to your test image
img = cv2.imread('/content/drive/MyDrive/FINAL_AI/FINAL_AI/anh (8).jpg')

default_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray_img, 1.3, 5)
#faces = face_cascade.detectMultiScale(gray_img, 4, 6)

faces_img = np.copy(gray_img)

plt.rcParams["axes.grid"] = False


all_x_cords = []
all_y_cords = []

for i, (x,y,w,h) in enumerate(faces):
    
    h += 10
    w += 10
    x -= 5
    y -= 5
    
    just_face = cv2.resize(gray_img[y:y+h,x:x+w], dimensions)
    cv2.rectangle(faces_img,(x,y),(x+w,y+h),(255,0,0),1)
    
    scale_val_x = w/96
    scale_val_y = h/96
    
    label_point = detect_points(just_face)
    all_x_cords.append((label_point[::2]*scale_val_x)+x)
    all_y_cords.append((label_point[1::2]*scale_val_y)+y)
   
   
    plt.imshow(just_face, cmap='gray')
    plt.plot(label_point[::2], label_point[1::2], 'ro', markersize=5)
    plt.show()
    
    
plt.imshow(default_img)    
plt.plot(all_x_cords, all_y_cords, 'wo',  markersize=3)
plt.show()
# Out:
# 1/1 [==============================] - 0s 261ms/step

# %%
#####  TEST YOUR IMAGE FILE WITH THE MODEL  #####


import cv2
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
import time

# Load the saved model
from keras.models import load_model
model = load_model('/content/drive/MyDrive/FINAL_AI/FINAL_AI/model1.h5')  # <-- Saved model path


def detect_points(face_img):
    me  = np.array(face_img)/255
    x_test = np.expand_dims(me, axis=0)
    x_test = np.expand_dims(x_test, axis=3)

    y_test = model.predict(x_test)
    label_points = (np.squeeze(y_test)*48)+48 
    
    return label_points
    
# Load haarcascade
face_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/FINAL_AI/FINAL_AI/haarcascade_frontalface_alt.xml')
dimensions = (96, 96)

# Enter the path to your test image
img = cv2.imread('/content/drive/MyDrive/FINAL_AI/FINAL_AI/hinh.jpg')

default_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray_img, 1.3, 5)
# faces = face_cascade.detectMultiScale(gray_img, 4, 6)

faces_img = np.copy(gray_img)

plt.rcParams["axes.grid"] = False


all_x_cords = []
all_y_cords = []

for i, (x,y,w,h) in enumerate(faces):
    
    h += 10
    w += 10
    x -= 5
    y -= 5
    
    just_face = cv2.resize(gray_img[y:y+h,x:x+w], dimensions)
    cv2.rectangle(faces_img,(x,y),(x+w,y+h),(255,0,0),1)
    
    scale_val_x = w/96
    scale_val_y = h/96
    
    label_point = detect_points(just_face)
    all_x_cords.append((label_point[::2]*scale_val_x)+x)
    all_y_cords.append((label_point[1::2]*scale_val_y)+y)
   
   
    plt.imshow(just_face, cmap='gray')
    plt.plot(label_point[::2], label_point[1::2], 'ro', markersize=5)
    plt.show()
    
    
plt.imshow(default_img)    
plt.plot(all_x_cords, all_y_cords, 'wo',  markersize=3)
plt.show()
# Out:
# 1/1 [==============================] - 0s 149ms/step

# %%
#####  TEST YOUR IMAGE FILE WITH THE MODEL  #####


import cv2
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
import time

# Load the saved model
from keras.models import load_model
model = load_model('/content/drive/MyDrive/FINAL_AI/FINAL_AI/model1.h5')  # <-- Saved model path


def detect_points(face_img):
    me  = np.array(face_img)/255
    x_test = np.expand_dims(me, axis=0)
    x_test = np.expand_dims(x_test, axis=3)

    y_test = model.predict(x_test)
    label_points = (np.squeeze(y_test)*48)+48 
    
    return label_points
    
# Load haarcascade
face_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/FINAL_AI/FINAL_AI/haarcascade_frontalface_alt.xml')
dimensions = (96, 96)

# Enter the path to your test image
img = cv2.imread('/content/drive/MyDrive/FINAL_AI/FINAL_AI/boy.jpg')

default_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray_img, 1.3, 5)
# faces = face_cascade.detectMultiScale(gray_img, 4, 6)

faces_img = np.copy(gray_img)

plt.rcParams["axes.grid"] = False


all_x_cords = []
all_y_cords = []

for i, (x,y,w,h) in enumerate(faces):
    
    h += 10
    w += 10
    x -= 5
    y -= 5
    
    just_face = cv2.resize(gray_img[y:y+h,x:x+w], dimensions)
    cv2.rectangle(faces_img,(x,y),(x+w,y+h),(255,0,0),1)
    
    scale_val_x = w/96
    scale_val_y = h/96
    
    label_point = detect_points(just_face)
    all_x_cords.append((label_point[::2]*scale_val_x)+x)
    all_y_cords.append((label_point[1::2]*scale_val_y)+y)
   
   
    plt.imshow(just_face, cmap='gray')
    plt.plot(label_point[::2], label_point[1::2], 'ro', markersize=5)
    plt.show()
    
    
plt.imshow(default_img)    
plt.plot(all_x_cords, all_y_cords, 'wo',  markersize=3)
plt.show()
# Out:
# 1/1 [==============================] - 0s 100ms/step

# %%
# import dependencies
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time


# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes


# initialize the Haar Cascade face detection model
face_cascade = cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'))


def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)

  # get photo data
  data = eval_js('takePhoto({})'.format(quality))
  # get OpenCV format image
  img = js_to_image(data) 
  # grayscale img
  gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
  print(gray.shape)
  # get face bounding box coordinates using Haar Cascade
  faces = face_cascade.detectMultiScale(gray)
 
  # save image
  cv2.imwrite(filename, img)

  return filename

from keras.models import load_model

# Load the saved model
model = load_model('/content/drive/MyDrive/FINAL_AI/FINAL_AI/model1.h5')  # <-- Saved model path

try:
    filename = take_photo('photo.jpg')
    print('Saved to {}'.format(filename))

    # Show the image which was just taken.
    display(Image(filename))

    def detect_points(face_img):
        me = np.array(face_img) / 255
        x_test = np.expand_dims(me, axis=0)
        x_test = np.expand_dims(x_test, axis=3)

        y_test = model.predict(x_test)
        label_points = (np.squeeze(y_test) * 48) + 48

        return label_points

    # Load haarcascade
    face_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/FINAL_AI/FINAL_AI/haarcascade_frontalface_alt.xml')
    dimensions = (96, 96)

    # Read the captured image
    img = cv2.imread(filename)

    default_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray_img, 1.3, 5)
    # faces = face_cascade.detectMultiScale(gray_img, 4, 6)

    faces_img = np.copy(gray_img)

    plt.rcParams["axes.grid"] = False

    all_x_cords = []
    all_y_cords = []

    for i, (x, y, w, h) in enumerate(faces):
        h += 10
        w += 10
        x -= 5
        y -= 5

        just_face = cv2.resize(gray_img[y:y+h, x:x+w], dimensions)
        cv2.rectangle(faces_img, (x, y), (x+w, y+h), (255, 0, 0), 1)

        scale_val_x = w / 96
        scale_val_y = h / 96

        label_point = detect_points(just_face)
        all_x_cords.append((label_point[::2] * scale_val_x) + x)
        all_y_cords.append((label_point[1::2] * scale_val_y) + y)

        plt.imshow(just_face, cmap='gray')
        plt.plot(label_point[::2], label_point[1::2], 'ro', markersize=5)
        plt.show()

    plt.imshow(default_img)
    plt.plot(all_x_cords, all_y_cords, 'wo', markersize=3)
    plt.show()

except Exception as err:
    # Errors will be thrown if the user does not have a webcam or if they do not
    # grant the page permission to access it.
    print(str(err))
# Out:
# (480, 640)
# Saved to photo.jpg
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe5e80dbbe0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 97ms/step
